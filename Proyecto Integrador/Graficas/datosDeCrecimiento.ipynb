# %% [markdown]
# # Graficas de datos de crecimiento para el proyecto integrador.
# Estas graficas tienen como objetivo probar la hipotesis de que la electro cultura es una forma viable para un crecimiento mas velos de las lechugas.

# %% [markdown]
# # Primer muestra de datos (Dilan)

# %% [markdown]
# ## Diagrama BoxPlot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Crear figura y ejes de graficado
fig, ax = plt.subplots(figsize=(12, 8))

# Datos sin antena
planta1 = [0.39,0.49,0.57,0.7,0.8,1.0,1.3,1.4,1.55,1.77,1.97,2.3,2.55,2.73,2.95,3.2,3.4,3.7,4.0,4.3,4.55,4.8,5.1,5.4,5.6]
planta2 = [0.22,0.32,0.46,0.53,0.63,0.7,0.9,1.1,1.2,1.3,1.5,1.6,1.8,2.0,2.2,2.5,2.7,2.85,3.0,3.2,3.5,3.7,4.0,4.2,4.35]
planta3 = [0.29,0.42,0.51,0.78,0.9,1.0,1.3,1.5,1.55,1.77,1.97,2.1,2.35,2.79,2.99,3.09,3.41,3.65,4.02,4.14,4.55,4.81,5.25,5.48,5.61]
planta4 = [0.18,0.39,0.44,0.71,0.98,1.01,1.34,1.46,1.59,1.74,1.87,2.32,2.75,2.93,2.95,3.21,3.44,3.75,4.10,4.32,4.65,4.88,5.12,5.34,5.65]
planta5 = [0.21,0.42,0.50,0.63,0.81,1.03,1.36,1.39,1.57,1.77,1.93,2.31,2.50,2.74,2.93,3.19,3.41,3.78,4.02,4.34,4.51,4.89,5.10,5.43,5.64]

# Combinar los datos en un solo array
data_sin_antena = [planta1, planta2, planta3, planta4, planta5]

# Datos con antena
planta12 = [0.5,0.9,1.2,1.5,1.8,2.2,2.6,2.95,3.37,3.7,3.93,4.45,4.9,5.4,5.93,6.6,7.3,7.8,8.3,8.7,9.3,9.9,10.6,11.1,11.6]
planta22 = [0.3,0.6,1.0,1.5,1.9,2.0,2.4,2.7,3.0,3.4,3.8,4.2,4.7,5.1,5.6,6.2,6.9,7.6,8.2,8.9,9.4,9.9,10.7,11.4,12.0]
planta32 = [0.7,0.8,1.2,1.8,1.9,2.3,2.7,2.9,3.7,3.8,3.9,4.4,4.8,5.2,5.4,6.4,6.8,7.2,7.5,8.0,9.3,9.9,10.2,11.8,12]
planta42 = [0.4,0.7,1.1,1.5,1.8,2.2,2.6,2.95,3.37,3.7,3.93,4.45,4.9,5.4,5.93,6.6,7.3,7.8,8.3,8.7,9.3,9.9,10.6,11.2,11.6]
planta52 = [0.1,0.2,1.2,1.1,1.5,2.1,2.2,2.7,3.3,3.5,3.9,4.4,4.9,5.1,5.2,6.2,6.3,7.1,7.4,8.8,9.3,9.6,10.1,11.7,12]

# Combinar los datos en un solo array
data_antena = [planta12, planta22, planta32, planta42, planta52]


# Crear diagramas de caja
boxplot_sin_antena = ax.boxplot(data_sin_antena, vert=True, patch_artist=True)
boxplot_antena = ax.boxplot(data_antena, vert=True, patch_artist=True)

# Algunos colores: ['lightblue', 'lightgreen', 'lightpink', 'lightyellow']
# Agregar colores
colors = ['lightgreen']*len(boxplot_sin_antena)
for patch, color in zip(boxplot_sin_antena['boxes'], colors):
    patch.set_facecolor(color)
    
# Agregar colores
colors = ['lightpink']*len(boxplot_antena)
for patch, color in zip(boxplot_antena['boxes'], colors):
    patch.set_facecolor(color)    
    
# Calcular medias para cada grupo y añadir lineas    
# Añadir linea que pasa por las medias
medians_sin_antena = [np.median(d) for d in data_sin_antena]  
ax.plot(range(1, len(medians_sin_antena) + 1), 
        medians_sin_antena, 
        marker='o', color='red', linestyle='dashed')

# Añadir linea que pasa por las medias
medians_antena = [np.median(d) for d in data_antena]  
ax.plot(range(1, len(medians_antena) + 1), 
        medians_antena, 
        marker='o', color='blue', linestyle='dashed')

# Personalizando el grosor y color de la línea de la mediana
median_color_sin_antena = 'green'
median_color_antena = 'magenta'
for caja in range(len(data_sin_antena)):
    median_line_sin = boxplot_sin_antena['medians'][caja]  
    median_line_con = boxplot_antena['medians'][caja]      
    median_line_sin.set_linewidth(2)  
    median_line_con.set_linewidth(2)  
    median_line_sin.set_color(median_color_sin_antena)  
    median_line_con.set_color(median_color_antena)      

    
# Añadir etiquetas y titulos
ax.set_xlabel('Mediciones por planta', fontsize=20)
ax.set_ylabel('Altura (cm)', fontsize=20)
ax.set_title('Crecimiento de la lechuga', fontsize=30)

ax.tick_params(axis='x', labelsize=15)  
ax.tick_params(axis='y', labelsize=15)  

# Exportar imagen
plt.savefig("m1_BoxPlot_Lechugas.png", dpi = 500, bbox_inches = 'tight', transparent = True)

# Mostrar plot con cuadricula
plt.grid()
plt.show()

# %% [markdown]
# ## Diagrama de Lollipop con datos de crecimiento sin antenas

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos sin antena
planta1_sin_antena = [0.39,0.49,0.57,0.7,0.8,1.0,1.3,1.4,1.55,1.77,1.97,2.3,2.55,2.73,2.95,3.2,3.4,3.7,4.0,4.3,4.55,4.8,5.1,5.4,5.6]
planta2_sin_antena = [0.22,0.32,0.46,0.53,0.63,0.7,0.9,1.1,1.2,1.3,1.5,1.6,1.8,2.0,2.2,2.5,2.7,2.85,3.0,3.2,3.5,3.7,4.0,4.2,4.35]
planta3_sin_antena = [0.29,0.42,0.51,0.78,0.9,1.0,1.3,1.5,1.55,1.77,1.97,2.1,2.35,2.79,2.99,3.09,3.41,3.65,4.02,4.14,4.55,4.81,5.25,5.48,5.61]
planta4_sin_antena = [0.18,0.39,0.44,0.71,0.98,1.01,1.34,1.46,1.59,1.74,1.87,2.32,2.75,2.93,2.95,3.21,3.44,3.75,4.10,4.32,4.65,4.88,5.12,5.34,5.65]
planta5_sin_antena = [0.21,0.42,0.50,0.63,0.81,1.03,1.36,1.39,1.57,1.77,1.93,2.31,2.50,2.74,2.93,3.19,3.41,3.78,4.02,4.34,4.51,4.89,5.10,5.43,5.64]

# Definir días
dias = np.arange(1, len(planta1_sin_antena) + 1)

# Crear ojiva
plt.figure(figsize=(10, 5))
plt.plot(dias, planta1_sin_antena, marker='o', label='Lechuga 1')
plt.plot(dias, planta2_sin_antena, marker='o', label='Lechuga 2')
plt.plot(dias, planta3_sin_antena, marker='o', label='Lechuga 3')
plt.plot(dias, planta4_sin_antena, marker='o', label='Lechuga 4')
plt.plot(dias, planta5_sin_antena, marker='o', label='Lechuga 5')
plt.title('Crecimiento de lechugas sin antena')
plt.xlabel('Días')
plt.ylabel('Tamaño (cm)')
plt.legend()

# Exportar imagen
plt.savefig("m1_Lollipop_sinAntena.png", dpi = 500, bbox_inches = 'tight', transparent = True)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Diagrama de Lollipop con datos de crecimiento con antenas

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos con antena
planta1_con_antena = [0.5,0.9,1.2,1.5,1.8,2.2,2.6,2.95,3.37,3.7,3.93,4.45,4.9,5.4,5.93,6.6,7.3,7.8,8.3,8.7,9.3,9.9,10.6,11.1,11.6]
planta2_con_antena = [0.3,0.6,1.0,1.5,1.9,2.0,2.4,2.7,3.0,3.4,3.8,4.2,4.7,5.1,5.6,6.2,6.9,7.6,8.2,8.9,9.4,9.9,10.7,11.4,12.0]
planta3_con_antena = [0.7,0.8,1.2,1.8,1.9,2.3,2.7,2.9,3.7,3.8,3.9,4.4,4.8,5.2,5.4,6.4,6.8,7.2,7.5,8.0,9.3,9.9,10.2,11.8,12]
planta4_con_antena = [0.4,0.7,1.1,1.5,1.8,2.2,2.6,2.95,3.37,3.7,3.93,4.45,4.9,5.4,5.93,6.6,7.3,7.8,8.3,8.7,9.3,9.9,10.6,11.2,11.6]
planta5_con_antena = [0.1,0.2,1.2,1.1,1.5,2.1,2.2,2.7,3.3,3.5,3.9,4.4,4.9,5.1,5.2,6.2,6.3,7.1,7.4,8.8,9.3,9.6,10.1,11.7,12]

# Definir días
dias = np.arange(1, len(planta1_con_antena) + 1)

# Crear ojiva
plt.figure(figsize=(10, 5))
plt.plot(dias, planta1_con_antena, marker='o', label='Lechuga 1')
plt.plot(dias, planta2_con_antena, marker='o', label='Lechuga 2')
plt.plot(dias, planta3_con_antena, marker='o', label='Lechuga 3')
plt.plot(dias, planta4_con_antena, marker='o', label='Lechuga 4')
plt.plot(dias, planta5_con_antena, marker='o', label='Lechuga 5')
plt.title('Crecimiento de lechugas con antena')
plt.xlabel('Días')
plt.ylabel('Tamaño (cm)')
plt.legend()
plt.savefig("m1_Lollipop_Antena.png", dpi = 500, bbox_inches = 'tight', transparent = True)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Diagrama de Lollipop con datos de crecimiento diarios para ambos

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos sin antena
planta1_sin_antena = [0.39,0.49,0.57,0.7,0.8,1.0,1.3,1.4,1.55,1.77,1.97,2.3,2.55,2.73,2.95,3.2,3.4,3.7,4.0,4.3,4.55,4.8,5.1,5.4,5.6]
planta2_sin_antena = [0.22,0.32,0.46,0.53,0.63,0.7,0.9,1.1,1.2,1.3,1.5,1.6,1.8,2.0,2.2,2.5,2.7,2.85,3.0,3.2,3.5,3.7,4.0,4.2,4.35]
planta3_sin_antena = [0.29,0.42,0.51,0.78,0.9,1.0,1.3,1.5,1.55,1.77,1.97,2.1,2.35,2.79,2.99,3.09,3.41,3.65,4.02,4.14,4.55,4.81,5.25,5.48,5.61]
planta4_sin_antena = [0.18,0.39,0.44,0.71,0.98,1.01,1.34,1.46,1.59,1.74,1.87,2.32,2.75,2.93,2.95,3.21,3.44,3.75,4.10,4.32,4.65,4.88,5.12,5.34,5.65]
planta5_sin_antena = [0.21,0.42,0.50,0.63,0.81,1.03,1.36,1.39,1.57,1.77,1.93,2.31,2.50,2.74,2.93,3.19,3.41,3.78,4.02,4.34,4.51,4.89,5.10,5.43,5.64]

# Datos con antena
planta1_con_antena = [0.5,0.9,1.2,1.5,1.8,2.2,2.6,2.95,3.37,3.7,3.93,4.45,4.9,5.4,5.93,6.6,7.3,7.8,8.3,8.7,9.3,9.9,10.6,11.1,11.6]
planta2_con_antena = [0.3,0.6,1.0,1.5,1.9,2.0,2.4,2.7,3.0,3.4,3.8,4.2,4.7,5.1,5.6,6.2,6.9,7.6,8.2,8.9,9.4,9.9,10.7,11.4,12.0]
planta3_con_antena = [0.7,0.8,1.2,1.8,1.9,2.3,2.7,2.9,3.7,3.8,3.9,4.4,4.8,5.2,5.4,6.4,6.8,7.2,7.5,8.0,9.3,9.9,10.2,11.8,12]
planta4_con_antena = [0.4,0.7,1.1,1.5,1.8,2.2,2.6,2.95,3.37,3.7,3.93,4.45,4.9,5.4,5.93,6.6,7.3,7.8,8.3,8.7,9.3,9.9,10.6,11.2,11.6]
planta5_con_antena = [0.1,0.2,1.2,1.1,1.5,2.1,2.2,2.7,3.3,3.5,3.9,4.4,4.9,5.1,5.2,6.2,6.3,7.1,7.4,8.8,9.3,9.6,10.1,11.7,12]

# Definir días
dias_sin_antena = np.arange(1, len(planta1_sin_antena) + 1)
dias_con_antena = np.arange(1, len(planta1_con_antena) + 1)

# Crear gráfico
plt.figure(figsize=(10, 5))
plt.plot(dias_sin_antena, planta1_sin_antena, marker='o', label='Planta 1 sin antena')
plt.plot(dias_sin_antena, planta2_sin_antena, marker='o', label='Planta 2 sin antena')
plt.plot(dias_sin_antena, planta3_sin_antena, marker='o', label='Planta 3 sin antena')
plt.plot(dias_sin_antena, planta4_sin_antena, marker='o', label='Planta 4 sin antena')
plt.plot(dias_sin_antena, planta5_sin_antena, marker='o', label='Planta 5 sin antena')
plt.plot(dias_con_antena, planta1_con_antena, marker='o', linestyle='--', label='Planta 1 con antena')
plt.plot(dias_con_antena, planta2_con_antena, marker='o', linestyle='--', label='Planta 2 con antena')
plt.plot(dias_con_antena, planta3_con_antena, marker='o', linestyle='--', label='Planta 3 con antena')
plt.plot(dias_con_antena, planta4_con_antena, marker='o', linestyle='--', label='Planta 4 con antena')
plt.plot(dias_con_antena, planta5_con_antena, marker='o', linestyle='--', label='Planta 5 con antena')
plt.title('Crecimiento diario de lechugas')
plt.xlabel('Días')
plt.ylabel('Tamaño (cm)')
plt.legend()
plt.grid(True)

# Guardar gráfico como PNG
plt.savefig("m1_Lollipop_DiarioLechugas.png", dpi = 500, bbox_inches = 'tight', transparent = True)
plt.grid(True)
plt.show()

# %% [markdown]
# # Segunda muestra de datos (Alejandro)

# %% [markdown]
# ## Diagrama BoxPlot

# %%
import matplotlib.pyplot as plt # type: ignore
import numpy as np # type: ignore

# Crear figura y ejes de graficado
fig, ax = plt.subplots(figsize=(12, 8))

# Datos sin antena
data1 = [0.3, 0.4, 0.5, 0.7, 0.8, 1, 1.3, 1.4, 1.55, 1.79, 1.97, 2.3, 2.55, 2.73, 2.95, 3.2, 3.4, 3.7, 4, 4.3, 4.55, 4.8, 5.1, 5.4, 5.6]
data2 = [0.2, 0.3, 0.5, 0.7, 0.9, 1.1, 1.2, 1.3, 1.5, 1.6, 1.8, 2, 2.2, 2.5, 2.7, 2.85, 3, 3.2, 3.5, 3.7, 4, 4.2, 4.35, 4.4, 4.5]
data3 = [0.4, 0.5 ,0.73, 0.9, 1.1,1.25, 1.33, 1.52, 1.78, 1.95, 2.18, 2.37, 2.62, 2.78, 2.95, 3.15, 3.4, 3.7, 3.9, 4.2 ,4.56, 4.8, 5.3, 5.8, 6.1]

# Combinar los datos en un solo array
data_sin_antena = [data1, data2, data3]

# Datos con antena
data1 = [0.5, 0.9, 1.2, 1.5, 1.8, 2.2, 2.6, 2.95, 3.37, 3.7, 3.93, 4.45, 4.9, 5.4, 5.93, 6.6, 7.3, 7.8, 8.3, 8.7, 9.3, 9.9, 10.6, 11.1, 11.6]
data2 = [0.3, 0.6, 1, 1.3, 1.6, 2, 2.4, 2.7, 3, 3.4, 3.8, 4.2, 4.7, 5.1, 5.6, 6.2, 6.9, 7.6, 8.2, 8.9, 9.4, 9.9, 10.7, 11.4, 12]
data3 = [0.2, 0.6, 0.9, 1.3 ,1.8, 2.3, 2.7, 3, 3.5, 3.95, 4.5, 4.9, 5.4, 6, 6.7, 7.3, 8.1, 8.6, 9, 9.5, 10.25, 10.65, 11.2, 11.5, 11.9]


# Combinar los datos en un solo array
data_antena = [data1, data2, data3]


# Crear diagramas de caja
boxplot_sin_antena = ax.boxplot(data_sin_antena, vert=True, patch_artist=True)
boxplot_antena = ax.boxplot(data_antena, vert=True, patch_artist=True)

# Algunos colores: ['lightblue', 'lightgreen', 'lightpink', 'lightyellow']
# Agregar colores
colors = ['lightgreen']*len(boxplot_sin_antena)
for patch, color in zip(boxplot_sin_antena['boxes'], colors):
    patch.set_facecolor(color)
    
# Agregar colores
colors = ['lightpink']*len(boxplot_antena)
for patch, color in zip(boxplot_antena['boxes'], colors):
    patch.set_facecolor(color)    
    
# Calcular medias para cada grupo y añadir lineas    
# Añadir linea que pasa por las medias
medians_sin_antena = [np.median(d) for d in data_sin_antena]  
ax.plot(range(1, len(medians_sin_antena) + 1), 
        medians_sin_antena, 
        marker='o', color='red', linestyle='dashed')

# Añadir linea que pasa por las medias
medians_antena = [np.median(d) for d in data_antena]  
ax.plot(range(1, len(medians_antena) + 1), 
        medians_antena, 
        marker='o', color='blue', linestyle='dashed')

# Personalizando el grosor y color de la línea de la mediana
median_color_sin_antena = 'green'
median_color_antena = 'magenta'
for caja in range(len(data_sin_antena)):
    median_line_sin = boxplot_sin_antena['medians'][caja]  
    median_line_con = boxplot_antena['medians'][caja]      
    median_line_sin.set_linewidth(2)  
    median_line_con.set_linewidth(2)  
    median_line_sin.set_color(median_color_sin_antena)  
    median_line_con.set_color(median_color_antena)      

    
# Añadir etiquetas y titulos
ax.set_xlabel('Mediciones', fontsize=20)
ax.set_ylabel('Altura (cm)', fontsize=20)
ax.set_title('Crecimiento de la lechuga', fontsize=30)

ax.tick_params(axis='x', labelsize=15)  
ax.tick_params(axis='y', labelsize=15)  

# Exportar imagen
# plt.savefig("Cajas_transparente_500dpi.png", dpi = 500, 
#            bbox_inches = 'tight', transparent = True)

# Mostrar plot con cuadricula
plt.savefig("m2_BoxPlot_Lechugas.png", dpi = 500, bbox_inches = 'tight', transparent = True)
plt.grid(True)
plt.show()
ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Diagrama de Lollipop con datos de crecimiento sin antena

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de crecimiento de las lechugas en milímetros
lechuga_SA = [0.3, 0.4, 0.5, 0.7, 0.8, 1, 1.3, 1.4, 1.55, 1.79, 1.97, 2.3, 2.55, 2.73, 2.95, 3.2, 3.4, 3.7, 4, 4.3, 4.55, 4.8, 5.1, 5.4, 5.6]
lechuga_CA = [0.5, 0.9, 1.2, 1.5, 1.8, 2.2, 2.6, 2.95, 3.37, 3.7, 3.93, 4.45, 4.9, 5.4, 5.93, 6.6, 7.3, 7.8, 8.3, 8.7, 9.3, 9.9, 10.6, 11.1, 11.6]
lechuga_SA2 = [0.2, 0.3, 0.5, 0.7, 0.9, 1.1, 1.2, 1.3, 1.5, 1.6, 1.8, 2, 2.2, 2.5, 2.7, 2.85, 3, 3.2, 3.5, 3.7, 4, 4.2, 4.35, 4.4, 4.5]
lechuga_CA2 = [0.3, 0.6, 1, 1.3, 1.6, 2, 2.4, 2.7, 3, 3.4, 3.8, 4.2, 4.7, 5.1, 5.6, 6.2, 6.9, 7.6, 8.2, 8.9, 9.4, 9.9, 10.7, 11.4, 12]
lechuga_SA3 = [0.4, 0.5 ,0.73, 0.9, 1.1,1.25, 1.33, 1.52, 1.78, 1.95, 2.18, 2.37, 2.62, 2.78, 2.95, 3.15, 3.4, 3.7, 3.9, 4.2 ,4.56, 4.8, 5.3, 5.8, 6.1]
lechuga_CA3 = [0.2, 0.6, 0.9, 1.3 ,1.8, 2.3, 2.7, 3, 3.5, 3.95, 4.5, 4.9, 5.4, 6, 6.7, 7.3, 8.1, 8.6, 9, 9.5, 10.25, 10.65, 11.2, 11.5, 11.9]

# Días correspondientes
dias = range(1, 26)

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(12, 6))

# Generar la gráfica de lollipop
x = np.arange(len(dias))
ax.plot(x, [y for y in lechuga_SA], 'o-', color='blue', linewidth=2, label='Lechuga SA')

ax.plot(x, [y for y in lechuga_SA2], 'o-', color='green', linewidth=2, label='Lechuga SA2')

ax.plot(x, [y for y in lechuga_SA3], 'o-', color='purple', linewidth=2, label='Lechuga SA3')

ax.set_xticks(x)
ax.set_xticklabels(dias)

# Agregar etiquetas y título
ax.set_ylabel('Crecimiento (cm)')
ax.set_title('Crecimiento de lechugas sin antena')
ax.set_xlabel('Dias')
ax.legend()

# Mostrar la gráfica
plt.savefig("m2_Lollipop_SinAntena.png", dpi = 500, bbox_inches = 'tight', transparent = True)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Diagrama de Lollipop con datos de crecimiento con antena

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de crecimiento de las lechugas en milímetros

lechuga_CA = [0.5, 0.9, 1.2, 1.5, 1.8, 2.2, 2.6, 2.95, 3.37, 3.7, 3.93, 4.45, 4.9, 5.4, 5.93, 6.6, 7.3, 7.8, 8.3, 8.7, 9.3, 9.9, 10.6, 11.1, 11.6]

lechuga_CA2 = [0.3, 0.6, 1, 1.3, 1.6, 2, 2.4, 2.7, 3, 3.4, 3.8, 4.2, 4.7, 5.1, 5.6, 6.2, 6.9, 7.6, 8.2, 8.9, 9.4, 9.9, 10.7, 11.4, 12]

lechuga_CA3 = [0.2, 0.6, 0.9, 1.3 ,1.8, 2.3, 2.7, 3, 3.5, 3.95, 4.5, 4.9, 5.4, 6, 6.7, 7.3, 8.1, 8.6, 9, 9.5, 10.25, 10.65, 11.2, 11.5, 11.9]

# Días correspondientes
dias = range(1, 26)

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(12, 6))

# Generar la gráfica de lollipop
x = np.arange(len(dias))

ax.plot(x, [y for y in lechuga_CA], 'o-', color='red', linewidth=2, label='Lechuga CA')

ax.plot(x, [y for y in lechuga_CA2], 'o-', color='orange', linewidth=2, label='Lechuga CA2')

ax.plot(x, [y for y in lechuga_CA3], 'o-', color='brown', linewidth=2, label='Lechuga CA3')
ax.set_xticks(x)
ax.set_xticklabels(dias)

# Agregar etiquetas y título
ax.set_ylabel('Crecimiento (cm)')
ax.set_title('Crecimiento de lechugas con antena')
ax.set_xlabel('Dias')
ax.legend()

# Mostrar la gráfica
plt.savefig("m2_Lollipop_Antena.png", dpi = 500, bbox_inches = 'tight', transparent = True)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Diagrama de Lollipop con datos de crecimiento diarios para ambos

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de crecimiento de las lechugas en milímetros
lechuga_SA = [0.3, 0.4, 0.5, 0.7, 0.8, 1, 1.3, 1.4, 1.55, 1.79, 1.97, 2.3, 2.55, 2.73, 2.95, 3.2, 3.4, 3.7, 4, 4.3, 4.55, 4.8, 5.1, 5.4, 5.6]
lechuga_CA = [0.5, 0.9, 1.2, 1.5, 1.8, 2.2, 2.6, 2.95, 3.37, 3.7, 3.93, 4.45, 4.9, 5.4, 5.93, 6.6, 7.3, 7.8, 8.3, 8.7, 9.3, 9.9, 10.6, 11.1, 11.6]
lechuga_SA2 = [0.2, 0.3, 0.5, 0.7, 0.9, 1.1, 1.2, 1.3, 1.5, 1.6, 1.8, 2, 2.2, 2.5, 2.7, 2.85, 3, 3.2, 3.5, 3.7, 4, 4.2, 4.35, 4.4, 4.5]
lechuga_CA2 = [0.3, 0.6, 1, 1.3, 1.6, 2, 2.4, 2.7, 3, 3.4, 3.8, 4.2, 4.7, 5.1, 5.6, 6.2, 6.9, 7.6, 8.2, 8.9, 9.4, 9.9, 10.7, 11.4, 12]
lechuga_SA3 = [0.4, 0.5 ,0.73, 0.9, 1.1,1.25, 1.33, 1.52, 1.78, 1.95, 2.18, 2.37, 2.62, 2.78, 2.95, 3.15, 3.4, 3.7, 3.9, 4.2 ,4.56, 4.8, 5.3, 5.8, 6.1]
lechuga_CA3 = [0.2, 0.6, 0.9, 1.3 ,1.8, 2.3, 2.7, 3, 3.5, 3.95, 4.5, 4.9, 5.4, 6, 6.7, 7.3, 8.1, 8.6, 9, 9.5, 10.25, 10.65, 11.2, 11.5, 11.9]

# Días correspondientes
dias = range(1, 26)

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(12, 6))

# Generar la gráfica de lollipop
x = np.arange(len(dias))
ax.plot(x, [y for y in lechuga_SA], 'o-', color='blue', linewidth=2, label='Lechuga SA')
ax.plot(x, [y for y in lechuga_CA], 'o-', color='red', linewidth=2, label='Lechuga CA')
ax.plot(x, [y for y in lechuga_SA2], 'o-', color='green', linewidth=2, label='Lechuga SA2')
ax.plot(x, [y for y in lechuga_CA2], 'o-', color='orange', linewidth=2, label='Lechuga CA2')
ax.plot(x, [y for y in lechuga_SA3], 'o-', color='purple', linewidth=2, label='Lechuga SA3')
ax.plot(x, [y for y in lechuga_CA3], 'o-', color='brown', linewidth=2, label='Lechuga CA3')
ax.set_xticks(x)
ax.set_xticklabels(dias)

# Agregar etiquetas y título
ax.set_ylabel('Crecimiento (cm)')
ax.set_title('Crecimiento diario de lechugas')
ax.set_xlabel('Dias')
ax.legend()

# Mostrar la gráfica
plt.savefig("m2_Lollipop_DiarioLechugas.png", dpi = 500, bbox_inches = 'tight', transparent = True)
plt.grid(True)
plt.show()
